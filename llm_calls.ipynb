# %% [markdown]
# ## Connect and compare LLMs
#
# - Connect to the grok API and choose a model
# - Connect to the Gemini API and choose a model
# - Connect to the OpenAI API and choose 4o-mini
#
# ### Create a prompt and inject a little text snippet of your liking
# - The LLM should use the injected information to answer a question.
#
# ### Compare the outputs
# - Use the same method for every model.
# - Do you see differences?
#
# **Tipp:** for prompt injection you can either use string concatenation or the python String formatter.

# %%
from google import genai
import os
from dotenv import load_dotenv
from google.genai import types
from openai import OpenAI
import anthropic

# %%
load_dotenv()
# Access the API key using the variable name defined in the .env file
google_api_key = os.getenv("GOOGLE_API_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")
deepinfra_api_key = os.getenv("DEEPINFRA_API_KEY")

# %% [markdown]
# ## Google
#
# https://ai.google.dev/gemini-api/docs/text-generation?hl=de
# examples: https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb?hl=de#scrollTo=mIC0pLnJdI8m

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Why is the job marekt in switzerland so competitive?"
)
print(response.text)
# Out:
# The job market in Switzerland is indeed known for being highly competitive for several key reasons, primarily stemming from its high attractiveness combined with its relatively small size and specific requirements.
#
# Here are the main factors contributing to the competitiveness:
#
# 1.  **High Quality of Life & Attractive Salaries:**
#     *   **Magnet for Talent:** Switzerland consistently ranks among the top countries globally for quality of life, safety, political stability, excellent infrastructure, and stunning natural beauty.
#     *   **Lucrative Compensation:** Salaries in Switzerland are among the highest in the world, even when accounting for the high cost of living. This financial draw attracts top talent from across the globe.
#     *   **Result:** This combination means that for almost every desirable position, there's a large pool of highly qualified international and local candidates vying for the role.
#
# 2.  **Strong and Stable Economy:**
#     *   **Low Unemployment:** Switzerland typically enjoys very low unemployment rates, indicating a robust economy. However, this doesn't necessarily mean jobs are easy to find; it means the existing workforce is largely employed, and new positions often require specific skills.
#     *   **Key Industries:** The economy is strong in high-value sectors like pharmaceuticals, biotechnology, finance, insurance, luxury goods, precision engineering, and IT. These industries demand highly specialized skills and often attract the best professionals worldwide.
#
# 3.  **Small Market Size & Population:**
#     *   **Limited Positions:** Switzerland is a relatively small country with a population of around 8.8 million people. Compared to larger economies, the sheer number of available job positions is inherently more limited.
#     *   **Fewer Companies:** While home to many multinational corporations, the total number of companies and, consequently, job openings is smaller than in countries like Germany, France, or the UK.
#
# 4.  **High Level of Education & Local Talent Pool:**
#     *   **Excellent Education System:** Switzerland boasts a world-class education system with prestigious universities (like ETH Zurich and EPFL Lausanne) that produce highly skilled graduates.
#     *   **Strong Local Workforce:** This means companies often have access to a very capable local workforce. Foreign applicants are not just competing with other international candidates but also with equally, or sometimes even better, qualified Swiss nationals.
#
# 5.  **Language Requirements:**
#     *   **Multilingual Environment:** Switzerland has three main official languages: German, French, and Italian. While English is often the working language in international companies (especially in Zurich, Geneva, Basel), proficiency in one or more of the local languages is often a significant advantage, and sometimes a strict requirement, especially for roles involving client interaction or integration into a local team.
#     *   **Barrier to Entry:** For many, the language barrier can make finding a job and integrating culturally more challenging.
#
# 6.  **Immigration Policies & Quotas (Especially for Non-EU/EFTA Citizens):**
#     *   **Preference for Local/EU/EFTA:** Swiss immigration policies give preference to Swiss citizens, followed by citizens of EU/EFTA countries.
#     *   **Strict Quotas:** For non-EU/EFTA citizens, there are strict annual quotas for work permits. Employers typically need to demonstrate that they could not find a suitable candidate from Switzerland or the EU/EFTA before they can hire a non-EU/EFTA national. This significantly increases the bar for non-EU candidates, who often need to possess highly specialized skills that are in shortage.
#
# 7.  **Specialized Skill Sets:**
#     *   **Niche Expertise:** Due to the focus on high-value industries, many job openings require very specific, often advanced, technical or professional skills. Generalist roles are often harder to secure, and candidates need to demonstrate expertise in a particular niche.
#
# In summary, the Swiss job market is competitive because a large pool of highly qualified candidates (attracted by excellent salaries and quality of life) competes for a relatively limited number of highly specialized jobs, often with language requirements and strict immigration rules for non-EU citizens.

# %%
from google import genai
from google.genai import types

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Why is the job marekt in switzerland so competitive?",
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0) # Disables thinking
    ),
)
print(response.text)
# Out:
# The job market in Switzerland is indeed highly competitive, and several factors contribute to this:
#
# **1. High Salaries and Quality of Life:**
#
# * **Attractive Compensation:** Switzerland consistently ranks among countries with the highest average salaries globally. This, combined with low taxes in many cantons, makes it incredibly attractive for professionals seeking to maximize their earning potential.
# * **Excellent Quality of Life:** Beyond financial rewards, Switzerland offers a very high quality of life. This includes:
#     * **Stunning Natural Beauty:** The Alps, pristine lakes, and picturesque towns are a major draw.
#     * **Exceptional Public Services:** World-class healthcare, education, and public transportation.
#     * **Safety and Stability:** Switzerland is renowned for its low crime rates and political stability.
#     * **Cleanliness and Efficiency:** A well-organized and efficient society.
# * **Overall Lifestyle Package:** The combination of high salaries and an excellent quality of life creates a powerful magnet for talent worldwide.
#
# **2. Strong Economy and Diverse Industries:**
#
# * **Robust and Stable Economy:** Switzerland boasts one of the most stable and resilient economies in the world, with low unemployment rates. This creates a perception of job security.
# * **Key Sectors:** It's a global leader in several high-value industries:
#     * **Financial Services:** Banking, wealth management, insurance.
#     * **Pharmaceuticals & Life Sciences:** Major R&D hubs and headquarters for global giants.
#     * **High-Tech & Engineering:** Precision manufacturing, machinery, watchmaking.
#     * **Luxury Goods:** Renowned for its craftsmanship.
#     * **Tourism:** A significant contributor to the economy.
# * **Specialized Talent Demand:** These industries often require highly skilled and specialized professionals, leading to intense competition for top talent.
#
# **3. International Appeal and High Influx of Talent:**
#
# * **Multicultural Hub:** Switzerland is a very international country, with a significant expat population. Many global companies have their headquarters or major operations there, attracting talent from all over the world.
# * **EU/EFTA Freedom of Movement (Historically):** While recent changes and quotas have impacted this, the historical freedom of movement for EU/EFTA citizens has meant a continuous flow of qualified candidates seeking opportunities in Switzerland.
# * **"Brain Drain" from other regions:** In some cases, professionals from countries with less robust economies or lower salaries may see Switzerland as a highly desirable destination.
#
# **4. Language Requirements:**
#
# * **Multiple Official Languages:** Switzerland has four official languages: German, French, Italian, and Romansh. For many roles, especially those involving client interaction or local teams, proficiency in at least one, often two, of these languages is a significant advantage, and sometimes a strict requirement.
# * **English for International Roles:** While English is widely spoken in international companies and specific sectors (e.g., tech, pharma R&D), not knowing a local language can still be a barrier for many positions and for full integration.
# * **Added Layer of Competition:** Candidates who are fluent in a local language automatically have an edge over equally qualified candidates who are not.
#
# **5. Small Market Size (Relative to Demand):**
#
# * **Limited Number of Openings:** While the economy is strong, Switzerland is a relatively small country with a smaller overall job market compared to larger economies like Germany, France, or the UK. This means fewer positions are available for the high number of applicants.
# * **Internal Talent Pool:** Companies often prioritize local talent or those already within Switzerland, making it harder for international applicants to break in.
#
# **In summary, the competitiveness of the Swiss job market is a direct result of its incredibly attractive package: high salaries, excellent quality of life, a stable and innovative economy, and its appeal as an international hub. This creates a magnet for highly skilled professionals from around the globe, leading to a strong supply of talent vying for a relatively limited number of high-quality positions.**

# %% [markdown]
# # Openai
# https://platform.openai.com/docs/guides/text

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5-nano",
    input="Why is the job marekt in switzerland so competitive?"
)

print(response.output_text)
# Out:
# Short answer: Switzerland has a strong, high-cost economy with many skilled jobs, but a relatively small population and strict hiring rules. That combo creates intense competition for the best roles, especially in certain sectors and cities.
#
# Key reasons why the market feels competitive
# - Strong economy and high wages: Many companies can offer attractive salaries, so lots of candidates compete for top positions.
# - Small population, high demand for talent: Switzerland is prosperous but has a limited pool of workers, especially for specialized roles.
# - Sector concentration and hot spots: Finance and tech in Zurich; pharmaceuticals in Basel; international organizations and multinationals in Geneva/Lausanne. These hubs draw applicants from around the world.
# - High skill and qualification requirements: Many roles require advanced degrees, professional certifications, or local-recognition of foreign qualifications.
# - Language and local fit: German, French, Italian are important depending on the region. Bilingual/multilingual candidates and those who fit local work culture often have an edge.
# - Immigration/work-permit rules: For non-EU/EFTA workers, there are stricter quotas and permit requirements; even EU/EFTA citizens face priority rules in many cases. This can limit supply for employers and intensify competition for the few available spots.
# - Lengthy and thorough hiring processes: Swiss employers often use multi-step interviews, tests, and reference checks, which can feel slow and rigorous.
# - Cost of living vs. salaries: The high cost of living means employers and candidates alike are serious about compensation and benefits, which can drive selective hiring.
#
# Practical tips to improve your chances
# - Clarify your eligibility: If you’re EU/EFTA, you generally have easier access; if not, research visa/permit requirements and employer sponsorship realities for your field.
# - Target in-demand sectors and roles: Focus on areas with shortages (e.g., IT, engineering, life sciences, analytics, certain trades) and roles where Swiss firms actively hire internationals.
# - Build Swiss-relevant credentials: Get recognized qualifications, certifications, or local training that Swiss employers value. If possible, pursue internships or trainee programs in Switzerland.
# - Learn the local language: Even basic fluency in German (Zurich/Basel), French (Geneva/Lausanne), or Italian (Ticino) significantly improves prospects and integration.
# - Network strategically: Use LinkedIn, alumni networks, local meetups, and industry events. Personal referrals matter a lot in Switzerland.
# - Gain Swiss experience where you can: Short-term contracts, graduate programs, or project-based roles can open doors to permanent positions.
# - Tailor your application to the Swiss market: CVs and cover letters with concise summaries of skills, concrete achievements, and a focus on reliability, punctuality, and teamwork.
# - Use multiple channels: Job portals (popular ones include general boards and specialized ones), company career pages, recruitment agencies, and cantonal employment services where applicable.
# - Be patient and persistent: Hiring timelines can be longer than some other markets. Short-term setbacks don’t necessarily mean you’re not a fit.
#
# If you’d like, tell me your field, your nationality/work-permit status, which canton/city you’re targeting, and your current language skills. I can tailor a concrete plan, including in-demand roles to aim for, a sample Swiss-style CV, and a step-by-step permit checklist.

# %% [markdown]
# # Deepinfra
# https://deepinfra.com/docs/openai_api
#
# goal: llama-3.3-70b-versatile

# %%
from openai import OpenAI

openai = OpenAI(
    api_key= deepinfra_api_key,
    base_url="https://api.deepinfra.com/v1/openai",
)

stream = True # or False

chat_completion = openai.chat.completions.create(
    model="meta-llama/Meta-Llama-3-8B-Instruct",
    messages=[{"role": "user", "content": "Hello"}],
    stream=stream,
)

if stream:
    for event in chat_completion:
        if event.choices[0].finish_reason:
            print(event.choices[0].finish_reason,
                  event.usage['prompt_tokens'],
                  event.usage['completion_tokens'])
        else:
            print(event.choices[0].delta.content)
else:
    print(chat_completion.choices[0].message.content)
    print(chat_completion.usage.prompt_tokens, chat_completion.usage.completion_tokens)


print(llm.choices[0].message.content)
# Out:
# Hello
# !
#  It
# 's
#  nice
#  to
#  meet
#  you
# .
#  Is
#  there
#  something
#  I
#  can
#  help
#  you
#  with
# ,
#  or
#  would
#  you
#  like
#  to
#  chat
# ?
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 20
#      17 for event in chat_completion:
#      18     if event.choices[0].finish_reason:
#      19         print(event.choices[0].finish_reason,
# ---> 20               event.usage['prompt_tokens'],
#      21               event.usage['completion_tokens'])
#      22     else:
#      23         print(event.choices[0].delta.content)
#
# TypeError: 'CompletionUsage' object is not subscriptable

# %% [markdown]
# ## Deepinfra
# https://deepinfra.com/docs/openai_api
#
# goals:
# - llama-3.3-X
# - gemma x x x
# - Qwen x x x
# - deepseek x x x

# %%
aimport io
import base64
from PIL import Image
from openai import OpenAI

client = OpenAI(
    api_key="$DEEPINFRA_TOKEN",
    base_url="https://api.deepinfra.com/v1/openai"
)

if __name__ == "__main__":
    response = client.images.generate(
        prompt="A photo of an astronaut riding a horse on Mars.",
        size="1024x1024",
        quality="standard",
        n=1,
    )
    b64_json = response.data[0].b64_json
    image_bytes = base64.b64decode(b64_json)
    image = Image.open(io.BytesIO(image_bytes))
    image.save("output.png")from openai import OpenAI

openai = OpenAI(
    api_key="$DEEPINFRA_TOKEN",
    base_url="https://api.deepinfra.com/v1/openai",
)

stream = True # or False

chat_completion = openai.chat.completions.create(
    model="meta-llama/Meta-Llama-3-8B-Instruct",
    messages=[
        {"role": "system", "content": "Respond like a michelin starred chef."},
        {"role": "user", "content": "Can you name at least two different techniques to cook lamb?"},
        {"role": "assistant", "content": "Bonjour! Let me tell you, my friend, cooking lamb is an art form, and I'm more than happy to share with you not two, but three of my favorite techniques to coax out the rich, unctuous flavors and tender textures of this majestic protein. First, we have the classic \"Sous Vide\" method. Next, we have the ancient art of \"Sous le Sable\". And finally, we have the more modern technique of \"Hot Smoking.\""},
        {"role": "user", "content": "Tell me more about the second method."},
    ],
    stream=stream,
)

if stream:
    for event in chat_completion:
        if event.choices[0].finish_reason:
            print(event.choices[0].finish_reason,
                  event.usage['prompt_tokens'],
                  event.usage['completion_tokens'])
        else:
            print(event.choices[0].delta.content)
else:
    print(chat_completion.choices[0].message.content)
    print(chat_completion.usage.prompt_tokens, chat_completion.usage.completion_tokens)
# Out:
# ---------------------------------------------------------------------------
# UnprocessableEntityError                  Traceback (most recent call last)
# Cell In[7], line 12
#       6 client = OpenAI(
#       7     api_key= deepinfra_api_key,
#       8     base_url="https://api.deepinfra.com/v1/openai"
#       9 )
#      11 if __name__ == "__main__":
# ---> 12     response = client.images.generate(
#      13         prompt="A photo of an astronaut riding a horse on Mars.",
#      14         size="1024x1024",
#      15         quality="standard",
#      16         n=1,
#      17     )
#      18     b64_json = response.data[0].b64_json
#      19     image_bytes = base64.b64decode(b64_json)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/openai/resources/images.py:873, in Images.generate(self, prompt, background, model, moderation, n, output_compression, output_format, partial_images, quality, response_format, size, stream, style, user, extra_headers, extra_query, extra_body, timeout)
#     845 @required_args(["prompt"], ["prompt", "stream"])
#     846 def generate(
#     847     self,
#    (...)    871     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     872 ) -> ImagesResponse | Stream[ImageGenStreamEvent]:
# --> 873     return self._post(
#     874         "/images/generations",
#     875         body=maybe_transform(
#     876             {
#     877                 "prompt": prompt,
#     878                 "background": background,
#     879                 "model": model,
#     880                 "moderation": moderation,
#     881                 "n": n,
#     882                 "output_compression": output_compression,
#     883                 "output_format": output_format,
#     884                 "partial_images": partial_images,
#     885                 "quality": quality,
#     886                 "response_format": response_format,
#     887                 "size": size,
#     888                 "stream": stream,
#     889                 "style": style,
#     890                 "user": user,
#     891             },
#     892             image_generate_params.ImageGenerateParamsStreaming
#     893             if stream
#     894             else image_generate_params.ImageGenerateParamsNonStreaming,
#     895         ),
#     896         options=make_request_options(
#     897             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     898         ),
#     899         cast_to=ImagesResponse,
#     900         stream=stream or False,
#     901         stream_cls=Stream[ImageGenStreamEvent],
#     902     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# UnprocessableEntityError: Error code: 422 - {'detail': [{'type': 'missing', 'loc': ['body', 'model'], 'msg': 'Field required', 'input': {'prompt': 'A photo of an astronaut riding a horse on Mars.', 'n': 1, 'quality': 'standard', 'size': '1024x1024'}}]}

# %% [markdown]
# ## Anthropic
#
# https://docs.claude.com/en/docs/get-started#python

# %%
import anthropic

client = anthropic.Anthropic()

message = client.messages.create(
    model="claude-sonnet-4-5",
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "Why is the job marekt in switzerland so competitive?"
        }
    ]
)
print(message.content)
# Out:
# [TextBlock(citations=None, text='# Why Switzerland\'s Job Market is Highly Competitive\n\n## Key Factors:\n\n**1. High Salaries & Quality of Life**\n- Among the highest wages globally\n- Excellent work-life balance and benefits\n- Attracts talent from across Europe and beyond\n\n**2. Small Market, Big Demand**\n- Population of only ~8.7 million\n- Limited number of positions available\n- High demand from both locals and foreigners\n\n**3. Language Requirements**\n- Multiple language expectations (German/French/Italian + English)\n- Creates barriers but also crowding among qualified multilingual candidates\n\n**4. Preference for Local/EU Candidates**\n- Swiss and EU citizens don\'t need work permits\n- Strict quotas for non-EU workers\n- Employers often prefer candidates already in Switzerland\n\n**5. High Qualification Standards**\n- Companies expect excellent education and experience\n- Strong emphasis on specific Swiss qualifications or equivalent\n- Apprenticeship system creates well-trained local competition\n\n**6. Network-Driven Hiring**\n- Many jobs filled through personal connections\n- "Hidden job market" is significant\n- Outsiders face disadvantages\n\n**7. Industry Concentration**\n- Finance, pharma, and tech are dominant but specialized\n- Limited opportunities outside major sectors\n\nThe combination of desirability and structural barriers makes Switzerland\'s job market particularly challenging for newcomers, despite strong economic conditions.', type='text')]
