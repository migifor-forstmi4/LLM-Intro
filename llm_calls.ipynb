# %% [markdown]
# ## Connect and compare LLMs
#
# - Connect to the grok API and choose a model
# - Connect to the Gemini API and choose a model
# - Connect to the OpenAI API and choose 4o-mini
#
# ### Create a prompt and inject a little text snippet of your liking
# - The LLM should use the injected information to answer a question.
#
# ### Compare the outputs
# - Use the same method for every model.
# - Do you see differences?
#
# **Tipp:** for prompt injection you can either use string concatenation or the python String formatter.

# %%
from google import genai
import os
from dotenv import load_dotenv
from google.genai import types
from openai import OpenAI
import anthropic

# %%
load_dotenv()
# Access the API key using the variable name defined in the .env file
google_api_key = os.getenv("GOOGLE_API_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")
deepinfra_api_key = os.getenv("DEEPINFRA_API_KEY")

# %% [markdown]
# ## Google
#
# https://ai.google.dev/gemini-api/docs/text-generation?hl=de
# examples: https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb?hl=de#scrollTo=mIC0pLnJdI8m

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Why is the job marekt in switzerland so competitive?"
)
print(response.text)
# Out:
# The job market in Switzerland is indeed highly competitive for a variety of reasons, making it challenging for both Swiss nationals and foreigners to secure positions. Here are the main factors contributing to this competitiveness:
#
# 1.  **High Salaries and Excellent Quality of Life:** Switzerland consistently ranks among the countries with the highest average salaries globally and offers an exceptional quality of life (safety, healthcare, education, infrastructure, natural beauty). This acts as a powerful magnet for highly skilled professionals from all over the world.
#
# 2.  **Economic Stability and Low Unemployment Rate:** Switzerland boasts a very stable economy with one of the lowest unemployment rates in Europe. While this is a positive indicator of a healthy economy, it also means there are fewer job openings relative to the number of qualified job seekers, intensifying competition for available roles.
#
# 3.  **Highly Skilled Local and International Workforce:**
#     *   **Strong Education System:** Switzerland has an excellent education system, producing a highly qualified local workforce, often multilingual.
#     *   **International Talent Pool:** Its attractiveness draws in a large pool of international talent, many of whom are highly educated and experienced, further increasing the number of strong candidates vying for the same positions.
#
# 4.  **Strong Industry Clusters:** Switzerland is a global leader in specific, high-value industries such as pharmaceuticals, finance, luxury goods, precision engineering, research & development, and certain tech sectors. These industries naturally attract top talent globally, making roles within them particularly competitive.
#
# 5.  **Employer Selectivity and High Expectations:** Due to the abundance of qualified applicants, Swiss employers can afford to be very selective. They often seek candidates with highly specific skills, extensive experience, and a strong cultural fit. There's a premium placed on qualifications and a proven track record.
#
# 6.  **Language Barriers:** While English is widely spoken in international companies and specific industries (especially tech and pharma), proficiency in one of Switzerland's official languages (German, French, or Italian, depending on the region) is often a significant advantage or even a requirement for many roles. This can be a barrier for non-native speakers.
#
# 7.  **Immigration and Visa Considerations (Even for EU/EFTA):**
#     *   **Non-EU/EFTA:** For candidates from outside the EU/EFTA, securing a work permit is highly challenging, typically requiring an employer to prove that no suitable Swiss or EU/EFTA candidate could be found.
#     *   **EU/EFTA:** While EU/EFTA citizens benefit from freedom of movement, employers may still prefer candidates already residing in Switzerland or those with highly specialized skills that are scarce locally. The sheer volume of EU/EFTA applicants means competition remains fierce.
#
# 8.  **Networking Culture:** As in many countries, strong professional networks can be crucial. Many jobs are filled through referrals or contacts, making it harder for those without an existing network in Switzerland to break in.
#
# In summary, the Swiss job market is competitive because it's a highly desirable place to live and work, attracting a large pool of top-tier talent, while simultaneously having a relatively small number of job openings due to its stable, low-unemployment economy and highly productive workforce.

# %%
from google import genai
from google.genai import types

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Why is the job marekt in switzerland so competitive?",
    config=types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0) # Disables thinking
    ),
)
print(response.text)
# Out:
# The job market in Switzerland is indeed known for being highly competitive. Several factors contribute to this:
#
# **1. High Salaries and Excellent Quality of Life:**
#
# * **Attractive Compensation:** Switzerland boasts some of the highest salaries globally across many sectors. This, combined with the low tax burden in some cantons, means a very high net income.
# * **Exceptional Quality of Life:** The country consistently ranks among the top for quality of life, offering stunning natural beauty, excellent public services (healthcare, education, transport), low crime rates, and a stable political environment.
# * **Strong Economy:** Switzerland has a robust and diversified economy with low unemployment rates. This economic stability makes it an attractive place to work and live, even during global downturns.
#
# **2. Limited Size and High Demand:**
#
# * **Small Population:** Switzerland is a relatively small country with a population of around 8.8 million. While the economy is strong, the absolute number of job openings is naturally smaller than in larger economies.
# * **International Appeal:** The factors above make Switzerland a highly desirable destination for talented professionals from all over the world. This creates a massive pool of international applicants vying for a limited number of positions.
# * **EU/EFTA Freedom of Movement:** For citizens of EU/EFTA countries, there are fewer bureaucratic hurdles to work in Switzerland (though permits are still required), further increasing the applicant pool from these regions.
#
# **3. Specific Industry Needs and Skill Gaps:**
#
# * **Specialized Economy:** Switzerland's economy is heavily focused on highly specialized sectors like pharmaceuticals, biotechnology, finance, watchmaking, high-tech manufacturing, and research.
# * **Demand for Niche Skills:** Companies often seek candidates with very specific, highly specialized skills and experience. If your skills don't perfectly align with these needs, it can be harder to find a suitable role.
# * **Language Requirements:** While many international companies operate in English, proficiency in one of Switzerland's national languages (German, French, Italian) is often a significant advantage, and sometimes a necessity, especially for roles involving client interaction or integration into the local culture. This can be a barrier for some international applicants.
#
# **4. Company Culture and Recruitment Practices:**
#
# * **Emphasis on Experience and Qualifications:** Swiss companies often place a high value on relevant work experience, strong academic qualifications, and a proven track record.
# * **Networking is Crucial:** As in many competitive markets, professional networking plays a very significant role in securing job opportunities. Many positions are filled through personal recommendations or internal referrals.
# * **Rigorous Interview Processes:** Recruitment processes can be lengthy and rigorous, involving multiple interview rounds, assessments, and extensive background checks.
#
# **In summary, the competitiveness stems from a confluence of high demand from exceptionally qualified individuals (both domestic and international) attracted by unparalleled living standards and compensation, coupled with a relatively small, highly specialized job market.**
#
# If you're looking to work in Switzerland, it's crucial to be highly qualified, persistent, and strategic in your job search, tailoring your applications to specific roles and potentially learning a local language.

# %% [markdown]
# # Openai
# https://platform.openai.com/docs/guides/text

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5-nano",
    input="Why is the job marekt in switzerland so competitive?"
)

print(response.output_text)
# Out:
# Short answer: Switzerland has a large, high-value economy with a relatively small, very skilled workforce. That combination makes many jobs in demand and the competition for the best roles fierce.
#
# Key factors driving the competitiveness:
# - High GDP and low unemployment: Switzerland consistently has strong economic growth and low joblessness, which keeps demand for skilled workers high.
# - Small, highly educated population: A limited pool of talent (despite excellent education and apprenticeships) means openings often outpace supply, especially in STEM, finance, pharma, and engineering.
# - Broad, high-value sectors: Finance, life sciences (pharma/biotech), technology, precision manufacturing, and healthcare regularly seek specialists, managers, and researchers.
# - High wages and living costs: Salaries are attractive, which draws in many applicants and raises the bar for qualifications and experience. The cost of living also means employers and workers have high expectations.
# - Language and regional variety: Switzerland is multilingual (German, French, Italian, Romansh in some areas) and highly cantonal. Local language skills and cultural fit are crucial, which can limit opportunities for non-natives if they don’t speak the local language.
# - Immigration and permits: Non-EU/EFTA workers face quotas and a rigorous permit process; EU/EFTA nationals have smoother access. This creates competition among applicants from different regions and makes the hiring process more selective.
# - Labour market structure: Strong emphasis on qualifications, certifications, and sometimes Swiss work experience or recognition of foreign credentials. Many roles are filled through networks and hidden job markets, not just postings.
# - Cross-border dynamics: A lot of workers commute from neighboring countries, affecting supply in some regions and occupational segments.
#
# What this means for job seekers or employers:
# - For job seekers: focus on in-demand fields (e.g., IT, engineering, life sciences, healthcare) and improve local language skills. Build a Swiss-style CV, network in cantonal or sector-specific groups, and be prepared for a potentially lengthy permit process if you’re not EU/EFTA.
# - For employers: be ready to sponsor permits where possible, invest in onboarding and language training, and leverage local networks and internships to access the talent pool.
#
# If you tell me your field, country of origin, and target canton/region, I can tailor a more specific picture and give practical steps to improve the odds in the Swiss job market.

# %% [markdown]
# # Deepinfra
# https://deepinfra.com/docs/openai_api
#
# goal: llama-3.3-70b-versatile

# %%
from openai import OpenAI

openai = OpenAI(
    api_key= deepinfra_api_key,
    base_url="https://api.deepinfra.com/v1/openai",
)

stream = True # or False

chat_completion = openai.chat.completions.create(
    model="meta-llama/Meta-Llama-3-8B-Instruct",
    messages=[{"role": "user", "content": "Hello"}],
    stream=stream,
)

if stream:
    for event in chat_completion:
        if event.choices[0].finish_reason:
            print(event.choices[0].finish_reason,
                  event.usage['prompt_tokens'],
                  event.usage['completion_tokens'])
        else:
            print(event.choices[0].delta.content)
else:
    print(chat_completion.choices[0].message.content)
    print(chat_completion.usage.prompt_tokens, chat_completion.usage.completion_tokens)


print(llm.choices[0].message.content)
# Out:
# Hello
# !
#  It
# 's
#  nice
#  to
#  meet
#  you
# .
#  Is
#  there
#  something
#  I
#  can
#  help
#  you
#  with
# ,
#  or
#  would
#  you
#  like
#  to
#  chat
# ?
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 20
#      17 for event in chat_completion:
#      18     if event.choices[0].finish_reason:
#      19         print(event.choices[0].finish_reason,
# ---> 20               event.usage['prompt_tokens'],
#      21               event.usage['completion_tokens'])
#      22     else:
#      23         print(event.choices[0].delta.content)
#
# TypeError: 'CompletionUsage' object is not subscriptable

# %% [markdown]
# ## Deepinfra
# https://deepinfra.com/docs/openai_api
#
# goals:
# - llama-3.3-X
# - gemma x x x
# - Qwen x x x
# - deepseek x x x

# %%
import io
import base64
from PIL import Image
from openai import OpenAI

client = OpenAI(
    api_key="$DEEPINFRA_TOKEN",
    base_url="https://api.deepinfra.com/v1/openai"
)

if __name__ == "__main__":
    response = client.images.generate(
        prompt="A photo of an astronaut riding a horse on Mars.",
        size="1024x1024",
        quality="standard",
        n=1,
    )
    b64_json = response.data[0].b64_json
    image_bytes = base64.b64decode(b64_json)
    image = Image.open(io.BytesIO(image_bytes))
    image.save("output.png")
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[8], line 12
#       6 client = OpenAI(
#       7     api_key="$DEEPINFRA_TOKEN",
#       8     base_url="https://api.deepinfra.com/v1/openai"
#       9 )
#      11 if __name__ == "__main__":
# ---> 12     response = client.images.generate(
#      13         prompt="A photo of an astronaut riding a horse on Mars.",
#      14         size="1024x1024",
#      15         quality="standard",
#      16         n=1,
#      17     )
#      18     b64_json = response.data[0].b64_json
#      19     image_bytes = base64.b64decode(b64_json)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/openai/resources/images.py:873, in Images.generate(self, prompt, background, model, moderation, n, output_compression, output_format, partial_images, quality, response_format, size, stream, style, user, extra_headers, extra_query, extra_body, timeout)
#     845 @required_args(["prompt"], ["prompt", "stream"])
#     846 def generate(
#     847     self,
#    (...)    871     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     872 ) -> ImagesResponse | Stream[ImageGenStreamEvent]:
# --> 873     return self._post(
#     874         "/images/generations",
#     875         body=maybe_transform(
#     876             {
#     877                 "prompt": prompt,
#     878                 "background": background,
#     879                 "model": model,
#     880                 "moderation": moderation,
#     881                 "n": n,
#     882                 "output_compression": output_compression,
#     883                 "output_format": output_format,
#     884                 "partial_images": partial_images,
#     885                 "quality": quality,
#     886                 "response_format": response_format,
#     887                 "size": size,
#     888                 "stream": stream,
#     889                 "style": style,
#     890                 "user": user,
#     891             },
#     892             image_generate_params.ImageGenerateParamsStreaming
#     893             if stream
#     894             else image_generate_params.ImageGenerateParamsNonStreaming,
#     895         ),
#     896         options=make_request_options(
#     897             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     898         ),
#     899         cast_to=ImagesResponse,
#     900         stream=stream or False,
#     901         stream_cls=Stream[ImageGenStreamEvent],
#     902     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'detail': 'User is not authorized to access this resource'}

# %% [markdown]
# ## Anthropic
#
# https://docs.claude.com/en/docs/get-started#python

# %%
import anthropic

client = anthropic.Anthropic()

message = client.messages.create(
    model="claude-sonnet-4-5",
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "Why is the job marekt in switzerland so competitive?"
        }
    ]
)
print(message.content)
# Out:
# [TextBlock(citations=None, text='# Why Switzerland\'s Job Market is Highly Competitive\n\n## Key Factors:\n\n**1. High Salaries & Quality of Life**\n- Among the highest wages globally\n- Excellent work-life balance and benefits\n- Attracts talent from across Europe and beyond\n\n**2. Small Market, Big Demand**\n- Population of only ~8.7 million\n- Limited number of positions available\n- High demand from both locals and foreigners\n\n**3. Language Requirements**\n- Multiple language expectations (German/French/Italian + English)\n- Creates barriers but also crowding among qualified multilingual candidates\n\n**4. Preference for Local/EU Candidates**\n- Swiss and EU citizens don\'t need work permits\n- Strict quotas for non-EU workers\n- Employers often prefer candidates already in Switzerland\n\n**5. High Qualification Standards**\n- Companies expect excellent education and experience\n- Strong emphasis on specific Swiss qualifications or equivalent\n- Apprenticeship system creates well-trained local competition\n\n**6. Network-Driven Hiring**\n- Many jobs filled through personal connections\n- "Hidden job market" is significant\n- Outsiders face disadvantages\n\n**7. Industry Concentration**\n- Finance, pharma, and tech are dominant but specialized\n- Limited opportunities outside major sectors\n\nThe combination of desirability and structural barriers makes Switzerland\'s job market particularly challenging for newcomers, despite strong economic conditions.', type='text')]
